# %% [markdown]
# # POS Tagging (Part-of-Speech Tagging)
# POS Tagging is the process of labeling each word in a sentence with its grammatical role — noun, verb, adjective, etc.
#
# # Common POS Tags
#
# | Tag | Meaning                         | Example            |
# |-----|----------------------------------|--------------------|
# | NN  | Noun (singular)                 | dog, car           |
# | NNS | Noun (plural)                   | dogs, cars         |
# | VB  | Verb (base form)                | run, eat           |
# | VBD | Verb (past tense)               | ran, ate           |
# | JJ  | Adjective                       | happy, big         |
# | RB  | Adverb                          | quickly, very      |
# | PRP | Personal pronoun                | he, she, they      |
# | DT  | Determiner                      | the, a, an         |
# | IN  | Preposition                     | in, on, at         |
# | CC  | Coordinating conjunction        | and, but, or       |
#
# ### Why is POS Tagging Important?
#
# - Word sense disambiguation — "bank" as noun (financial) vs verb (to bank on)
# - Named Entity Recognition (NER) — finding names, places
# - Parsing sentence structure
# - Information extraction
# - Machine translation

# %% [markdown]
# ## Implement Using spaCy

# %%
# !pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.11-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.12-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.10-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.2-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy)
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer_slim-0.24.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from spacy) (2.3.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\kisha\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\kisha\appdata\roaming\python\python313\site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kisha\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\kisha\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.10.5)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.3-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\kisha\appdata\roaming\python\python313\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting typer>=0.24.0 (from typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\kisha\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: wrapt in c:\users\kisha\appdata\roaming\python\python313\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.0.1)
# Requirement already satisfied: click>=8.2.1 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\kisha\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.0)
# Requirement already satisfied: rich>=12.3.0 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (14.2.0)
# Collecting annotated-doc>=0.0.2 (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kisha\appdata\roaming\python\python313\site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.11-cp313-cp313-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.2 MB 2.3 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/14.2 MB 1.7 MB/s eta 0:00:08
#    -- ------------------------------------- 1.0/14.2 MB 1.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.6/14.2 MB 1.8 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.8/14.2 MB 1.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 2
MB/s eta 0:00:03
#    ------------------ --------------------- 2.9/6.2 MB 1.5 MB/s eta 0:00:03
#    -------------------- ------------------- 3.1/6.2 MB 1.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.4/6.2 MB 1.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.7/6.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------- -------------- 3.9/6.2 MB 1.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.5/6.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------------ --------- 4.7/6.2 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 5.0/6.2 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 1.4 MB/s  0:00:04
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading typer_slim-0.24.0-py3-none-any.whl (3.4 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.3-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, murmurhash, cymem, cloudpathlib, catalogue, blis, annotated-doc, srsly, preshed, typer, confection, typer-slim, thinc, weasel, spacy
#
#    ---- -----------------------------------  2/17 [spacy-legacy]
#    ----------- ----------------------------  5/17 [cloudpathlib]
#    ---------------- -----------------------  7/17 [blis]
#    --------------------- ------------------  9/17 [srsly]
#    --------------------- ------------------  9/17 [srsly]
#    --------------------- ------------------  9/17 [srsly]
#    --------------------- ------------------  9/17 [srsly]
#   Attempting uninstall: typer
#    --------------------- ------------------  9/17 [srsly]
#    ------------------------- -------------- 11/17 [typer]
#     Found existing installation: typer 0.9.0
#    ------------------------- -------------- 11/17 [typer]
#     Uninstalling typer-0.9.0:
#    ------------------------- -------------- 11/17 [typer]
#       Successfully uninstalled typer-0.9.0
#    ------------------------- -------------- 11/17 [typer]
#    ------------------------- -------------- 11/17 [typer]
#    -------------------------------- ------- 14/17 [thinc]
#    -------------------------------- ------- 14/17 [thinc]
#    -------------------------------- ------- 14/17 [thinc]
#    -------------------------------- ------- 14/17 [thinc]
#    -------------------------------- ------- 14/17 [thinc]
#    ----------------------------------- ---- 15/17 [weasel]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ------------------------------------- -- 16/17 [spacy]
#    ---------------------------------------- 17/17 [spacy]
#
# Successfully installed annotated-doc-0.0.4 blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.12 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 thinc-8.3.10 typer-0.24.1 typer-slim-0.24.0 wasabi-1.1.3 weasel-0.4.3
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
# python -m spacy download en_core_web_sm   => Install using CMD terminal
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("I love machine learning every day")

# %%
for token in doc:
    print(f"{token.text:<15} {token.pos_:<10} {token.tag_:<10} {spacy.explain(token.tag_)}")
# Out:
# I               PRON       PRP        pronoun, personal
# love            VERB       VBP        verb, non-3rd person singular present
# machine         NOUN       NN         noun, singular or mass
# learning        VERB       VBG        verb, gerund or present participle
# every           DET        DT         determiner
# day             NOUN       NN         noun, singular or mass

# %% [markdown]
# ### Filtering Nouns Only

# %%
doc = nlp("The quick brown fox jumps over the lazy dog")

# Extract only nouns
nouns = [token.text for token in doc if token.pos_ == "NOUN"]
print(nouns)  # ['fox', 'dog']

# Extract only verbs
verbs = [token.text for token in doc if token.pos_ == "VERB"]
print(verbs)  # ['jumps']
# Out:
# ['fox', 'dog']
# ['jumps']
